# %%
import os
import json
import pandas as pd
import tqdm

# %%
import nltk
from nltk import pos_tag, word_tokenize, RegexpParser

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def extract_verb_phrases(text):
    words = word_tokenize(text)
    tagged_words = pos_tag(words)

    # extract VP and NP with regexp
    grammar = r"""
        VP: {<MD>?<VB.*><NP|PP>*}
        NP: {<DT>?<JJ.*>*<NN.*>+}
        PP: {<IN><NP>}
        RP: {<RP><NP>}
    """
    chunk_parser = RegexpParser(grammar)
    tree = chunk_parser.parse(tagged_words)
    
    vc_list = []
    vc = ""
    vc_c = 0
    for subtree in tree:
        if type(subtree) is not tuple:
            if subtree.label() == "VP":
                if len(vc) > 0: ## If there is a verb phrase before it, add it to the list
                    if vc_c == 1: ## Exclude when verbs appear consecutively
                        pass
                    else:
                        vc_list.append(vc)
                    vc_c = 0
                    vc = ""
                
                if subtree[0][1] != "VBZ" and subtree[0][0] != "happened": ## Exclude Be verb, happened   
                    vc = " ".join([word for word, tag in subtree.leaves()])
                    vc_c += 1
            else:
                if len(vc) > 0:
                    vc += " " + " ".join([word for word, tag in subtree.leaves()])
                    vc_c += 1
        else:
            if subtree[1] in ["RP", "IN"] and vc_c == 1: # Adverb immediately after verb (Cannot be detected by chunking)
                vc += " " + subtree[0]
                vc_c += 1
            elif len(vc) > 0:
                if vc_c == 1: ## Exclude single verb
                    pass
                else:
                    vc_list.append(vc)
                vc = ""
                vc_c = 0
    if vc_c > 1:
        vc_list.append(vc)
    
    #print(tree)
    return vc_list
# Out:
# [nltk_data] Downloading package punkt to /home/ubuntu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/ubuntu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# create folder for each dataset first

# %%
def save_json(content, save_path):
    with open(save_path, 'w') as f:
        f.write(json.dumps(content))
def load_jsonl(filename):
    with open(filename, "r") as f:
        return [json.loads(l.strip("\n")) for l in f.readlines()]

# %%
# STAR

# %%
train_path = '/data/VQA/data/star/STAR_train.json'
val_path = '/data/VQA/data/star/STAR_val.json'

# %%
train = json.load(open(train_path))
val = json.load(open(val_path))

# %%
new_train = []
new_val = []
for qa in train:
    qa_dict = {}
    qa_dict['video'] = qa['video_id']
    qa_dict['num_option'] = 4
    qa_dict['qid'] = qa['question_id']
    for i, choice in enumerate(qa['choices']):
        qa_dict['a{}'.format(str(i))] = choice['choice']
        if choice['choice'] == qa['answer']:
            answer = i
    qa_dict['answer'] = answer
    qa_dict['question'] = qa['question']
    qa_dict['q_events'] = extract_verb_phrases(qa['question'])
    
    qa_dict['start'] = qa['start']
    qa_dict['end'] = qa['end']
    new_train.append(qa_dict)

for qa in val:
    qa_dict = {}
    qa_dict['video'] = qa['video_id']
    qa_dict['num_option'] = 4
    qa_dict['qid'] = qa['question_id']
    for i, choice in enumerate(qa['choices']):
        qa_dict['a{}'.format(str(i))] = choice['choice']
        if choice['choice'] == qa['answer']:
            answer = i
    qa_dict['answer'] = answer
    qa_dict['question'] = qa['question']
    qa_dict['q_events'] = extract_verb_phrases(qa['question'])
    qa_dict['start'] = qa['start']
    qa_dict['end'] = qa['end']
    new_val.append(qa_dict)

# %%
len(new_train)
# Out:
# 45731

# %%
save_json(new_train, '/data/VQA/MELA/prep_json/star/train.json')
save_json(new_val, '/data/VQA/MELA/prep_json/star/val.json')

# %%
new_train
# Out:
# [{'video': 'TJZ0P',
#   'num_option': 4,
#   'qid': 'Interaction_T1_4',
#   'a0': 'The sandwich.',
#   'a1': 'The medicine.',
#   'a2': 'The blanket.',
#   'a3': 'The box.',
#   'answer': 0,
#   'question': 'Which object was eaten by the person?',
#   'q_events': ['eaten by the person'],
#   'start': 7.7,
#   'end': 15.7},
#  {'video': 'TJZ0P',
#   'num_option': 4,
#   'qid': 'Interaction_T1_5',
#   'a0': 'The book.',
#   'a1': 'The refrigerator.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The window.',
#   'answer': 0,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 6.7,
#   'end': 11.5},
#  {'video': 'B82GJ',
#   'num_option': 4,
#   'qid': 'Interaction_T1_7',
#   'a0': 'The food.',
#   'a1': 'The laptop.',
#   'a2': 'The towel.',
#   'a3': 'The broom.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 17.7,
#   'end': 22.5},
#  {'video': 'DUZDL',
#   'num_option': 4,
#   'qid': 'Interaction_T1_8',
#   'a0': 'The sofa/couch.',
#   'a1': 'The table.',
#   'a2': 'The bed.',
#   'a3': 'The floor.',
#   'answer': 2,
#   'question': 'Which object was sat on by the person?',
#   'q_events': ['sat'],
#   'start': 1.6,
#   'end': 7.8},
#  {'video': 'DUZDL',
#   'num_option': 4,
#   'qid': 'Interaction_T1_9',
#   'a0': 'The food.',
#   'a1': 'The broom.',
#   'a2': 'The shoe.',
#   'a3': 'The clothes.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 31.2,
#   'end': 40.1},
#  {'video': 'DUZDL',
#   'num_option': 4,
#   'qid': 'Interaction_T1_10',
#   'a0': 'The cup/glass/bottle.',
#   'a1': 'The clothes.',
#   'a2': 'The towel.',
#   'a3': 'The bag.',
#   'answer': 1,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 23.4,
#   'end': 30.6},
#  {'video': 'DUZDL',
#   'num_option': 4,
#   'qid': 'Interaction_T1_11',
#   'a0': 'The clothes.',
#   'a1': 'The towel.',
#   'a2': 'The blanket.',
#   'a3': 'The pillow.',
#   'answer': 2,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 1.4,
#   'end': 6.4},
#  {'video': 'DUZDL',
#   'num_option': 4,
#   'qid': 'Interaction_T1_12',
#   'a0': 'The bed.',
#   'a1': 'The sofa/couch.',
#   'a2': 'The floor.',
#   'a3': 'The bag.',
#   'answer': 0,
#   'question': 'Which object was lied on by the person?',
#   'q_events': ['lied'],
#   'start': 0.0,
#   'end': 5.2},
#  {'video': 'GM3UK',
#   'num_option': 4,
#   'qid': 'Interaction_T1_17',
#   'a0': 'The towel.',
#   'a1': 'The food.',
#   'a2': 'The bag.',
#   'a3': 'The box.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 3.0,
#   'end': 8.2},
#  {'video': 'GM3UK',
#   'num_option': 4,
#   'qid': 'Interaction_T1_19',
#   'a0': 'The phone/camera.',
#   'a1': 'The picture.',
#   'a2': 'The clothes.',
#   'a3': 'The bag.',
#   'answer': 0,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 12.0,
#   'end': 21.1},
#  {'video': 'GM3UK',
#   'num_option': 4,
#   'qid': 'Interaction_T1_20',
#   'a0': 'The towel.',
#   'a1': 'The broom.',
#   'a2': 'The blanket.',
#   'a3': 'The closet/cabinet.',
#   'answer': 0,
#   'question': 'Which object was tidied up by the person?',
#   'q_events': ['tidied up by the person'],
#   'start': 0.0,
#   'end': 9.9},
#  {'video': 'GM3UK',
#   'num_option': 4,
#   'qid': 'Interaction_T1_21',
#   'a0': 'The dish.',
#   'a1': 'The clothes.',
#   'a2': 'The table.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 2,
#   'question': 'Which object was washed by the person?',
#   'q_events': ['washed by the person'],
#   'start': 1.4,
#   'end': 6.4},
#  {'video': 'RS6EK',
#   'num_option': 4,
#   'qid': 'Interaction_T1_22',
#   'a0': 'The sandwich.',
#   'a1': 'The food.',
#   'a2': 'The phone/camera.',
#   'a3': 'The clothes.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 0.0,
#   'end': 7.5},
#  {'video': '5EEXF',
#   'num_option': 4,
#   'qid': 'Interaction_T1_23',
#   'a0': 'The window.',
#   'a1': 'The closet/cabinet.',
#   'a2': 'The door.',
#   'a3': 'The book.',
#   'answer': 1,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 5.9,
#   'end': 11.7},
#  {'video': '5EEXF',
#   'num_option': 4,
#   'qid': 'Interaction_T1_24',
#   'a0': 'The window.',
#   'a1': 'The refrigerator.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The bag.',
#   'answer': 2,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 1.0,
#   'end': 7.0},
#  {'video': '5EEXF',
#   'num_option': 4,
#   'qid': 'Interaction_T1_25',
#   'a0': 'The laptop.',
#   'a1': 'The box.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The door.',
#   'answer': 3,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 21.6,
#   'end': 31.0},
#  {'video': '5EEXF',
#   'num_option': 4,
#   'qid': 'Interaction_T1_27',
#   'a0': 'The window.',
#   'a1': 'The laptop.',
#   'a2': 'The door.',
#   'a3': 'The book.',
#   'answer': 2,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 14.6,
#   'end': 21.6},
#  {'video': 'VW4UD',
#   'num_option': 4,
#   'qid': 'Interaction_T1_28',
#   'a0': 'The dish.',
#   'a1': 'The table.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The clothes.',
#   'answer': 0,
#   'question': 'Which object was washed by the person?',
#   'q_events': ['washed by the person'],
#   'start': 21.3,
#   'end': 28.0},
#  {'video': 'VW4UD',
#   'num_option': 4,
#   'qid': 'Interaction_T1_29',
#   'a0': 'The clothes.',
#   'a1': 'The broom.',
#   'a2': 'The towel.',
#   'a3': 'The sandwich.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 14.7,
#   'end': 20.2},
#  {'video': 'VCYH8',
#   'num_option': 4,
#   'qid': 'Interaction_T1_30',
#   'a0': 'The dish.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The picture.',
#   'a3': 'The clothes.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 3.1,
#   'end': 7.2},
#  {'video': '4ALLQ',
#   'num_option': 4,
#   'qid': 'Interaction_T1_33',
#   'a0': 'The food.',
#   'a1': 'The clothes.',
#   'a2': 'The shoe.',
#   'a3': 'The towel.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 21.1,
#   'end': 26.9},
#  {'video': '4ALLQ',
#   'num_option': 4,
#   'qid': 'Interaction_T1_34',
#   'a0': 'The book.',
#   'a1': 'The towel.',
#   'a2': 'The clothes.',
#   'a3': 'The pillow.',
#   'answer': 1,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 21.1,
#   'end': 27.3},
#  {'video': 'SJ51G',
#   'num_option': 4,
#   'qid': 'Interaction_T1_53',
#   'a0': 'The blanket.',
#   'a1': 'The table.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The clothes.',
#   'answer': 0,
#   'question': 'Which object was tidied up by the person?',
#   'q_events': ['tidied up by the person'],
#   'start': 5.9,
#   'end': 13.2},
#  {'video': 'SJ51G',
#   'num_option': 4,
#   'qid': 'Interaction_T1_54',
#   'a0': 'The cup/glass/bottle.',
#   'a1': 'The blanket.',
#   'a2': 'The phone/camera.',
#   'a3': 'The bag.',
#   'answer': 1,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 16.0,
#   'end': 21.7},
#  {'video': 'A7WU3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_56',
#   'a0': 'The towel.',
#   'a1': 'The book.',
#   'a2': 'The broom.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 17.5,
#   'end': 23.8},
#  {'video': 'MZZ8Q',
#   'num_option': 4,
#   'qid': 'Interaction_T1_58',
#   'a0': 'The blanket.',
#   'a1': 'The bag.',
#   'a2': 'The shoe.',
#   'a3': 'The box.',
#   'answer': 2,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 9.7,
#   'end': 16.7},
#  {'video': '6IL0C',
#   'num_option': 4,
#   'qid': 'Interaction_T1_59',
#   'a0': 'The dish.',
#   'a1': 'The towel.',
#   'a2': 'The shoe.',
#   'a3': 'The blanket.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 14.2,
#   'end': 21.0},
#  {'video': '6IL0C',
#   'num_option': 4,
#   'qid': 'Interaction_T1_60',
#   'a0': 'The cup/glass/bottle.',
#   'a1': 'The book.',
#   'a2': 'The shoe.',
#   'a3': 'The pillow.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 0.0,
#   'end': 6.9},
#  {'video': 'AYZS4',
#   'num_option': 4,
#   'qid': 'Interaction_T1_63',
#   'a0': 'The food.',
#   'a1': 'The sandwich.',
#   'a2': 'The laptop.',
#   'a3': 'The towel.',
#   'answer': 3,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 29.3,
#   'end': 35.0},
#  {'video': 'AYZS4',
#   'num_option': 4,
#   'qid': 'Interaction_T1_64',
#   'a0': 'The bed.',
#   'a1': 'The sofa/couch.',
#   'a2': 'The floor.',
#   'a3': 'The table.',
#   'answer': 3,
#   'question': 'Which object was sat at by the person?',
#   'q_events': ['sat'],
#   'start': 0.0,
#   'end': 8.2},
#  {'video': 'AYZS4',
#   'num_option': 4,
#   'qid': 'Interaction_T1_66',
#   'a0': 'The clothes.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The book.',
#   'a3': 'The food.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 14.9,
#   'end': 21.9},
#  {'video': '6IHRD',
#   'num_option': 4,
#   'qid': 'Interaction_T1_67',
#   'a0': 'The bag.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The towel.',
#   'a3': 'The phone/camera.',
#   'answer': 1,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 7.7,
#   'end': 14.2},
#  {'video': 'CH41S',
#   'num_option': 4,
#   'qid': 'Interaction_T1_72',
#   'a0': 'The dish.',
#   'a1': 'The phone/camera.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The broom.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 2.3,
#   'end': 10.3},
#  {'video': 'UJVCW',
#   'num_option': 4,
#   'qid': 'Interaction_T1_73',
#   'a0': 'The clothes.',
#   'a1': 'The phone/camera.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The food.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 4.0,
#   'end': 10.3},
#  {'video': 'UJVCW',
#   'num_option': 4,
#   'qid': 'Interaction_T1_74',
#   'a0': 'The phone/camera.',
#   'a1': 'The box.',
#   'a2': 'The sandwich.',
#   'a3': 'The dish.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 4.7,
#   'end': 10.6},
#  {'video': 'QLGHA',
#   'num_option': 4,
#   'qid': 'Interaction_T1_75',
#   'a0': 'The dish.',
#   'a1': 'The towel.',
#   'a2': 'The phone/camera.',
#   'a3': 'The broom.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 3.3,
#   'end': 10.0},
#  {'video': 'UE638',
#   'num_option': 4,
#   'qid': 'Interaction_T1_77',
#   'a0': 'The book.',
#   'a1': 'The closet/cabinet.',
#   'a2': 'The door.',
#   'a3': 'The laptop.',
#   'answer': 2,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 0.0,
#   'end': 4.2},
#  {'video': 'CLAWJ',
#   'num_option': 4,
#   'qid': 'Interaction_T1_83',
#   'a0': 'The book.',
#   'a1': 'The closet/cabinet.',
#   'a2': 'The laptop.',
#   'a3': 'The door.',
#   'answer': 2,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 8.1,
#   'end': 13.9},
#  {'video': 'CLAWJ',
#   'num_option': 4,
#   'qid': 'Interaction_T1_84',
#   'a0': 'The laptop.',
#   'a1': 'The dish.',
#   'a2': 'The towel.',
#   'a3': 'The food.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 9.9,
#   'end': 15.6},
#  {'video': 'ALJ7B',
#   'num_option': 4,
#   'qid': 'Interaction_T1_85',
#   'a0': 'The blanket.',
#   'a1': 'The phone/camera.',
#   'a2': 'The dish.',
#   'a3': 'The clothes.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 2.1,
#   'end': 9.8},
#  {'video': 'ALJ7B',
#   'num_option': 4,
#   'qid': 'Interaction_T1_86',
#   'a0': 'The clothes.',
#   'a1': 'The food.',
#   'a2': 'The box.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 3,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 10.8,
#   'end': 15.5},
#  {'video': 'AWN1C',
#   'num_option': 4,
#   'qid': 'Interaction_T1_93',
#   'a0': 'The shoe.',
#   'a1': 'The sofa/couch.',
#   'a2': 'The floor.',
#   'a3': 'The bed.',
#   'answer': 2,
#   'question': 'Which object was lied on by the person?',
#   'q_events': ['lied'],
#   'start': 42.0,
#   'end': 47.0},
#  {'video': 'AWN1C',
#   'num_option': 4,
#   'qid': 'Interaction_T1_94',
#   'a0': 'The picture.',
#   'a1': 'The dish.',
#   'a2': 'The food.',
#   'a3': 'The towel.',
#   'answer': 1,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 0.0,
#   'end': 8.0},
#  {'video': 'ENOLD',
#   'num_option': 4,
#   'qid': 'Interaction_T1_107',
#   'a0': 'The box.',
#   'a1': 'The door.',
#   'a2': 'The book.',
#   'a3': 'The bag.',
#   'answer': 2,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 6.6,
#   'end': 13.0},
#  {'video': 'ENOLD',
#   'num_option': 4,
#   'qid': 'Interaction_T1_108',
#   'a0': 'The table.',
#   'a1': 'The sofa/couch.',
#   'a2': 'The bed.',
#   'a3': 'The floor.',
#   'answer': 0,
#   'question': 'Which object was sat at by the person?',
#   'q_events': ['sat'],
#   'start': 7.2,
#   'end': 17.0},
#  {'video': 'ENOLD',
#   'num_option': 4,
#   'qid': 'Interaction_T1_109',
#   'a0': 'The book.',
#   'a1': 'The sandwich.',
#   'a2': 'The blanket.',
#   'a3': 'The phone/camera.',
#   'answer': 0,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 6.6,
#   'end': 10.9},
#  {'video': '02DPI',
#   'num_option': 4,
#   'qid': 'Interaction_T1_115',
#   'a0': 'The picture.',
#   'a1': 'The box.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The book.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 29.0,
#   'end': 35.3},
#  {'video': '02DPI',
#   'num_option': 4,
#   'qid': 'Interaction_T1_116',
#   'a0': 'The food.',
#   'a1': 'The towel.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The blanket.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 21.3,
#   'end': 28.0},
#  {'video': 'SM4AO',
#   'num_option': 4,
#   'qid': 'Interaction_T1_120',
#   'a0': 'The food.',
#   'a1': 'The clothes.',
#   'a2': 'The bag.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 1.0,
#   'end': 9.3},
#  {'video': 'QH3WP',
#   'num_option': 4,
#   'qid': 'Interaction_T1_121',
#   'a0': 'The towel.',
#   'a1': 'The phone/camera.',
#   'a2': 'The pillow.',
#   'a3': 'The clothes.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 3.4,
#   'end': 9.1},
#  {'video': 'PUA7P',
#   'num_option': 4,
#   'qid': 'Interaction_T1_123',
#   'a0': 'The box.',
#   'a1': 'The dish.',
#   'a2': 'The book.',
#   'a3': 'The clothes.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 16.8,
#   'end': 26.0},
#  {'video': 'PUA7P',
#   'num_option': 4,
#   'qid': 'Interaction_T1_124',
#   'a0': 'The clothes.',
#   'a1': 'The bag.',
#   'a2': 'The food.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 1.7,
#   'end': 6.7},
#  {'video': 'PUA7P',
#   'num_option': 4,
#   'qid': 'Interaction_T1_125',
#   'a0': 'The towel.',
#   'a1': 'The food.',
#   'a2': 'The box.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 9.7,
#   'end': 15.3},
#  {'video': 'PUA7P',
#   'num_option': 4,
#   'qid': 'Interaction_T1_126',
#   'a0': 'The food.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The picture.',
#   'a3': 'The clothes.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 16.5,
#   'end': 26.0},
#  {'video': 'KE5EM',
#   'num_option': 4,
#   'qid': 'Interaction_T1_132',
#   'a0': 'The clothes.',
#   'a1': 'The bag.',
#   'a2': 'The food.',
#   'a3': 'The pillow.',
#   'answer': 0,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 4.8,
#   'end': 9.9},
#  {'video': 'KE5EM',
#   'num_option': 4,
#   'qid': 'Interaction_T1_133',
#   'a0': 'The refrigerator.',
#   'a1': 'The door.',
#   'a2': 'The bag.',
#   'a3': 'The book.',
#   'answer': 2,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 3.0,
#   'end': 8.8},
#  {'video': 'KE5EM',
#   'num_option': 4,
#   'qid': 'Interaction_T1_134',
#   'a0': 'The towel.',
#   'a1': 'The clothes.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The book.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 4.6,
#   'end': 9.3},
#  {'video': 'KE5EM',
#   'num_option': 4,
#   'qid': 'Interaction_T1_135',
#   'a0': 'The food.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The bag.',
#   'a3': 'The pillow.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 5.8,
#   'end': 10.6},
#  {'video': 'EURF2',
#   'num_option': 4,
#   'qid': 'Interaction_T1_141',
#   'a0': 'The bed.',
#   'a1': 'The floor.',
#   'a2': 'The table.',
#   'a3': 'The sofa/couch.',
#   'answer': 0,
#   'question': 'Which object was sat on by the person?',
#   'q_events': ['sat'],
#   'start': 22.5,
#   'end': 29.4},
#  {'video': 'EURF2',
#   'num_option': 4,
#   'qid': 'Interaction_T1_142',
#   'a0': 'The blanket.',
#   'a1': 'The table.',
#   'a2': 'The broom.',
#   'a3': 'The towel.',
#   'answer': 0,
#   'question': 'Which object was tidied up by the person?',
#   'q_events': ['tidied up by the person'],
#   'start': 13.9,
#   'end': 23.3},
#  {'video': 'EURF2',
#   'num_option': 4,
#   'qid': 'Interaction_T1_143',
#   'a0': 'The blanket.',
#   'a1': 'The laptop.',
#   'a2': 'The bag.',
#   'a3': 'The phone/camera.',
#   'answer': 0,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 1.2,
#   'end': 10.0},
#  {'video': 'TLDYG',
#   'num_option': 4,
#   'qid': 'Interaction_T1_144',
#   'a0': 'The pillow.',
#   'a1': 'The clothes.',
#   'a2': 'The picture.',
#   'a3': 'The food.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 5.8,
#   'end': 14.2},
#  {'video': 'FZAEP',
#   'num_option': 4,
#   'qid': 'Interaction_T1_145',
#   'a0': 'The door.',
#   'a1': 'The closet/cabinet.',
#   'a2': 'The box.',
#   'a3': 'The bag.',
#   'answer': 1,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 22.1,
#   'end': 30.9},
#  {'video': 'QI0EL',
#   'num_option': 4,
#   'qid': 'Interaction_T1_152',
#   'a0': 'The box.',
#   'a1': 'The pillow.',
#   'a2': 'The sandwich.',
#   'a3': 'The laptop.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 21.8,
#   'end': 26.4},
#  {'video': '165K2',
#   'num_option': 4,
#   'qid': 'Interaction_T1_158',
#   'a0': 'The pillow.',
#   'a1': 'The box.',
#   'a2': 'The food.',
#   'a3': 'The phone/camera.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 9.4,
#   'end': 16.5},
#  {'video': '165K2',
#   'num_option': 4,
#   'qid': 'Interaction_T1_159',
#   'a0': 'The clothes.',
#   'a1': 'The towel.',
#   'a2': 'The table.',
#   'a3': 'The blanket.',
#   'answer': 2,
#   'question': 'Which object was tidied up by the person?',
#   'q_events': ['tidied up by the person'],
#   'start': 0.4,
#   'end': 7.0},
#  {'video': 'T63X2',
#   'num_option': 4,
#   'qid': 'Interaction_T1_160',
#   'a0': 'The phone/camera.',
#   'a1': 'The laptop.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The bag.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 30.7,
#   'end': 35.8},
#  {'video': 'YVKIV',
#   'num_option': 4,
#   'qid': 'Interaction_T1_161',
#   'a0': 'The blanket.',
#   'a1': 'The broom.',
#   'a2': 'The bag.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 4.4,
#   'end': 9.2},
#  {'video': 'KNGRY',
#   'num_option': 4,
#   'qid': 'Interaction_T1_162',
#   'a0': 'The box.',
#   'a1': 'The pillow.',
#   'a2': 'The clothes.',
#   'a3': 'The dish.',
#   'answer': 0,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 17.1,
#   'end': 22.5},
#  {'video': 'KNGRY',
#   'num_option': 4,
#   'qid': 'Interaction_T1_163',
#   'a0': 'The box.',
#   'a1': 'The dish.',
#   'a2': 'The clothes.',
#   'a3': 'The food.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 15.4,
#   'end': 21.1},
#  {'video': 'ZDV60',
#   'num_option': 4,
#   'qid': 'Interaction_T1_164',
#   'a0': 'The towel.',
#   'a1': 'The book.',
#   'a2': 'The clothes.',
#   'a3': 'The shoe.',
#   'answer': 3,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 23.0,
#   'end': 29.3},
#  {'video': 'XMYXI',
#   'num_option': 4,
#   'qid': 'Interaction_T1_167',
#   'a0': 'The laptop.',
#   'a1': 'The sandwich.',
#   'a2': 'The phone/camera.',
#   'a3': 'The box.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 22.6,
#   'end': 29.2},
#  {'video': 'Y2MGC',
#   'num_option': 4,
#   'qid': 'Interaction_T1_168',
#   'a0': 'The box.',
#   'a1': 'The book.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The refrigerator.',
#   'answer': 0,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 11.5,
#   'end': 17.5},
#  {'video': 'Y2MGC',
#   'num_option': 4,
#   'qid': 'Interaction_T1_169',
#   'a0': 'The box.',
#   'a1': 'The closet/cabinet.',
#   'a2': 'The door.',
#   'a3': 'The refrigerator.',
#   'answer': 0,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 7.9,
#   'end': 15.1},
#  {'video': 'Y2MGC',
#   'num_option': 4,
#   'qid': 'Interaction_T1_170',
#   'a0': 'The picture.',
#   'a1': 'The paper/notebook.',
#   'a2': 'The laptop.',
#   'a3': 'The blanket.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 6.7,
#   'end': 13.1},
#  {'video': 'GA7SB',
#   'num_option': 4,
#   'qid': 'Interaction_T1_174',
#   'a0': 'The phone/camera.',
#   'a1': 'The box.',
#   'a2': 'The bag.',
#   'a3': 'The book.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 12.1,
#   'end': 16.2},
#  {'video': '3IPI3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_176',
#   'a0': 'The laptop.',
#   'a1': 'The bag.',
#   'a2': 'The refrigerator.',
#   'a3': 'The book.',
#   'answer': 3,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 10.0,
#   'end': 15.9},
#  {'video': '3IPI3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_177',
#   'a0': 'The sofa/couch.',
#   'a1': 'The bed.',
#   'a2': 'The sandwich.',
#   'a3': 'The medicine.',
#   'answer': 2,
#   'question': 'Which object was eaten by the person?',
#   'q_events': ['eaten by the person'],
#   'start': 7.9,
#   'end': 13.0},
#  {'video': 'T96JC',
#   'num_option': 4,
#   'qid': 'Interaction_T1_178',
#   'a0': 'The shoe.',
#   'a1': 'The phone/camera.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The dish.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 1.1,
#   'end': 8.2},
#  {'video': '8TSU4',
#   'num_option': 4,
#   'qid': 'Interaction_T1_179',
#   'a0': 'The picture.',
#   'a1': 'The food.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The box.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 8.4,
#   'end': 13.6},
#  {'video': '3G991',
#   'num_option': 4,
#   'qid': 'Interaction_T1_180',
#   'a0': 'The dish.',
#   'a1': 'The bag.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The clothes.',
#   'answer': 0,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 0.0,
#   'end': 9.2},
#  {'video': 'N2DZN',
#   'num_option': 4,
#   'qid': 'Interaction_T1_181',
#   'a0': 'The clothes.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The sandwich.',
#   'a3': 'The towel.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 13.7,
#   'end': 20.1},
#  {'video': 'N2DZN',
#   'num_option': 4,
#   'qid': 'Interaction_T1_182',
#   'a0': 'The clothes.',
#   'a1': 'The towel.',
#   'a2': 'The pillow.',
#   'a3': 'The shoe.',
#   'answer': 0,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 13.3,
#   'end': 19.1},
#  {'video': 'ZXHCH',
#   'num_option': 4,
#   'qid': 'Interaction_T1_190',
#   'a0': 'The bed.',
#   'a1': 'The floor.',
#   'a2': 'The table.',
#   'a3': 'The sofa/couch.',
#   'answer': 2,
#   'question': 'Which object was sat at by the person?',
#   'q_events': ['sat'],
#   'start': 19.3,
#   'end': 26.0},
#  {'video': 'ZXHCH',
#   'num_option': 4,
#   'qid': 'Interaction_T1_191',
#   'a0': 'The box.',
#   'a1': 'The dish.',
#   'a2': 'The phone/camera.',
#   'a3': 'The bag.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 17.9,
#   'end': 23.0},
#  {'video': '3IMTV',
#   'num_option': 4,
#   'qid': 'Interaction_T1_193',
#   'a0': 'The laptop.',
#   'a1': 'The box.',
#   'a2': 'The window.',
#   'a3': 'The door.',
#   'answer': 1,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 21.2,
#   'end': 29.1},
#  {'video': 'U1DE4',
#   'num_option': 4,
#   'qid': 'Interaction_T1_199',
#   'a0': 'The food.',
#   'a1': 'The towel.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The clothes.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 21.1,
#   'end': 29.5},
#  {'video': 'U1DE4',
#   'num_option': 4,
#   'qid': 'Interaction_T1_200',
#   'a0': 'The laptop.',
#   'a1': 'The door.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The bag.',
#   'answer': 1,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 20.1,
#   'end': 29.5},
#  {'video': 'U1DE4',
#   'num_option': 4,
#   'qid': 'Interaction_T1_201',
#   'a0': 'The door.',
#   'a1': 'The book.',
#   'a2': 'The refrigerator.',
#   'a3': 'The closet/cabinet.',
#   'answer': 3,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 24.1,
#   'end': 31.4},
#  {'video': 'CUQYX',
#   'num_option': 4,
#   'qid': 'Interaction_T1_202',
#   'a0': 'The sofa/couch.',
#   'a1': 'The bed.',
#   'a2': 'The floor.',
#   'a3': 'The window.',
#   'answer': 2,
#   'question': 'Which object was lied on by the person?',
#   'q_events': ['lied'],
#   'start': 0.0,
#   'end': 8.9},
#  {'video': 'CUQYX',
#   'num_option': 4,
#   'qid': 'Interaction_T1_203',
#   'a0': 'The cup/glass/bottle.',
#   'a1': 'The shoe.',
#   'a2': 'The pillow.',
#   'a3': 'The bag.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 24.3,
#   'end': 30.0},
#  {'video': 'CUQYX',
#   'num_option': 4,
#   'qid': 'Interaction_T1_205',
#   'a0': 'The window.',
#   'a1': 'The book.',
#   'a2': 'The bag.',
#   'a3': 'The door.',
#   'answer': 2,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 15.1,
#   'end': 21.3},
#  {'video': 'CUQYX',
#   'num_option': 4,
#   'qid': 'Interaction_T1_206',
#   'a0': 'The paper/notebook.',
#   'a1': 'The bag.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The food.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 28.5,
#   'end': 32.0},
#  {'video': 'CUQYX',
#   'num_option': 4,
#   'qid': 'Interaction_T1_207',
#   'a0': 'The bag.',
#   'a1': 'The refrigerator.',
#   'a2': 'The book.',
#   'a3': 'The door.',
#   'answer': 0,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 28.6,
#   'end': 32.0},
#  {'video': 'OETY6',
#   'num_option': 4,
#   'qid': 'Interaction_T1_209',
#   'a0': 'The food.',
#   'a1': 'The dish.',
#   'a2': 'The broom.',
#   'a3': 'The clothes.',
#   'answer': 1,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 14.0,
#   'end': 19.4},
#  {'video': 'H0Q6V',
#   'num_option': 4,
#   'qid': 'Interaction_T1_214',
#   'a0': 'The shoe.',
#   'a1': 'The clothes.',
#   'a2': 'The bag.',
#   'a3': 'The box.',
#   'answer': 0,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 4.2,
#   'end': 13.1},
#  {'video': 'GLSU2',
#   'num_option': 4,
#   'qid': 'Interaction_T1_216',
#   'a0': 'The box.',
#   'a1': 'The book.',
#   'a2': 'The door.',
#   'a3': 'The closet/cabinet.',
#   'answer': 3,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 13.1,
#   'end': 19.3},
#  {'video': 'GLSU2',
#   'num_option': 4,
#   'qid': 'Interaction_T1_217',
#   'a0': 'The book.',
#   'a1': 'The broom.',
#   'a2': 'The towel.',
#   'a3': 'The bag.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 23.8,
#   'end': 29.2},
#  {'video': 'GLSU2',
#   'num_option': 4,
#   'qid': 'Interaction_T1_218',
#   'a0': 'The blanket.',
#   'a1': 'The towel.',
#   'a2': 'The clothes.',
#   'a3': 'The picture.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 14.2,
#   'end': 19.7},
#  {'video': 'GQ341',
#   'num_option': 4,
#   'qid': 'Interaction_T1_228',
#   'a0': 'The bed.',
#   'a1': 'The floor.',
#   'a2': 'The table.',
#   'a3': 'The sofa/couch.',
#   'answer': 2,
#   'question': 'Which object was sat at by the person?',
#   'q_events': ['sat'],
#   'start': 0.0,
#   'end': 4.3},
#  {'video': '3HLP7',
#   'num_option': 4,
#   'qid': 'Interaction_T1_229',
#   'a0': 'The blanket.',
#   'a1': 'The picture.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The box.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 0.8,
#   'end': 7.2},
#  {'video': '9UU4W',
#   'num_option': 4,
#   'qid': 'Interaction_T1_230',
#   'a0': 'The pillow.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The clothes.',
#   'a3': 'The food.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 7.9,
#   'end': 15.5},
#  {'video': '9UU4W',
#   'num_option': 4,
#   'qid': 'Interaction_T1_231',
#   'a0': 'The towel.',
#   'a1': 'The clothes.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The food.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 20.2,
#   'end': 26.1},
#  {'video': '9UU4W',
#   'num_option': 4,
#   'qid': 'Interaction_T1_232',
#   'a0': 'The book.',
#   'a1': 'The bag.',
#   'a2': 'The door.',
#   'a3': 'The closet/cabinet.',
#   'answer': 1,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 14.5,
#   'end': 21.5},
#  {'video': 'YIG5G',
#   'num_option': 4,
#   'qid': 'Interaction_T1_240',
#   'a0': 'The food.',
#   'a1': 'The clothes.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The paper/notebook.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 9.9,
#   'end': 15.7},
#  {'video': 'YIG5G',
#   'num_option': 4,
#   'qid': 'Interaction_T1_241',
#   'a0': 'The towel.',
#   'a1': 'The clothes.',
#   'a2': 'The dish.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 7.0,
#   'end': 12.6},
#  {'video': '4H61U',
#   'num_option': 4,
#   'qid': 'Interaction_T1_242',
#   'a0': 'The sandwich.',
#   'a1': 'The clothes.',
#   'a2': 'The broom.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 11.9,
#   'end': 17.8},
#  {'video': 'TU9K1',
#   'num_option': 4,
#   'qid': 'Interaction_T1_250',
#   'a0': 'The closet/cabinet.',
#   'a1': 'The door.',
#   'a2': 'The box.',
#   'a3': 'The book.',
#   'answer': 1,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 37.0,
#   'end': 42.0},
#  {'video': 'TU9K1',
#   'num_option': 4,
#   'qid': 'Interaction_T1_251',
#   'a0': 'The clothes.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The book.',
#   'a3': 'The paper/notebook.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 20.1,
#   'end': 25.1},
#  {'video': 'TU9K1',
#   'num_option': 4,
#   'qid': 'Interaction_T1_252',
#   'a0': 'The laptop.',
#   'a1': 'The clothes.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The phone/camera.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 15.7,
#   'end': 21.0},
#  {'video': 'RON2M',
#   'num_option': 4,
#   'qid': 'Interaction_T1_253',
#   'a0': 'The door.',
#   'a1': 'The bag.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The window.',
#   'answer': 1,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 10.2,
#   'end': 19.5},
#  {'video': 'RON2M',
#   'num_option': 4,
#   'qid': 'Interaction_T1_254',
#   'a0': 'The pillow.',
#   'a1': 'The book.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The food.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 16.3,
#   'end': 23.2},
#  {'video': 'PCNUP',
#   'num_option': 4,
#   'qid': 'Interaction_T1_258',
#   'a0': 'The picture.',
#   'a1': 'The box.',
#   'a2': 'The blanket.',
#   'a3': 'The dish.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 4.3,
#   'end': 9.7},
#  {'video': 'PCNUP',
#   'num_option': 4,
#   'qid': 'Interaction_T1_259',
#   'a0': 'The book.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The sandwich.',
#   'a3': 'The clothes.',
#   'answer': 3,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 9.3,
#   'end': 13.8},
#  {'video': 'AGGSE',
#   'num_option': 4,
#   'qid': 'Interaction_T1_265',
#   'a0': 'The dish.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The clothes.',
#   'a3': 'The shoe.',
#   'answer': 1,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 17.2,
#   'end': 21.8},
#  {'video': 'GMPHO',
#   'num_option': 4,
#   'qid': 'Interaction_T1_270',
#   'a0': 'The food.',
#   'a1': 'The box.',
#   'a2': 'The pillow.',
#   'a3': 'The bag.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 31.4,
#   'end': 41.0},
#  {'video': 'GMPHO',
#   'num_option': 4,
#   'qid': 'Interaction_T1_271',
#   'a0': 'The food.',
#   'a1': 'The clothes.',
#   'a2': 'The bag.',
#   'a3': 'The broom.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 31.4,
#   'end': 41.0},
#  {'video': 'GMPHO',
#   'num_option': 4,
#   'qid': 'Interaction_T1_272',
#   'a0': 'The clothes.',
#   'a1': 'The bag.',
#   'a2': 'The picture.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 17.0,
#   'end': 22.8},
#  {'video': 'RAGOI',
#   'num_option': 4,
#   'qid': 'Interaction_T1_273',
#   'a0': 'The bag.',
#   'a1': 'The clothes.',
#   'a2': 'The pillow.',
#   'a3': 'The broom.',
#   'answer': 1,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 8.7,
#   'end': 12.0},
#  {'video': 'RAGOI',
#   'num_option': 4,
#   'qid': 'Interaction_T1_274',
#   'a0': 'The sofa/couch.',
#   'a1': 'The bed.',
#   'a2': 'The floor.',
#   'a3': 'The table.',
#   'answer': 0,
#   'question': 'Which object was sat on by the person?',
#   'q_events': ['sat'],
#   'start': 0.0,
#   'end': 6.8},
#  {'video': 'RAGOI',
#   'num_option': 4,
#   'qid': 'Interaction_T1_275',
#   'a0': 'The paper/notebook.',
#   'a1': 'The clothes.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The picture.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 5.0,
#   'end': 11.0},
#  {'video': 'HHNTA',
#   'num_option': 4,
#   'qid': 'Interaction_T1_276',
#   'a0': 'The pillow.',
#   'a1': 'The clothes.',
#   'a2': 'The book.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 1,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 23.9,
#   'end': 31.6},
#  {'video': 'HHNTA',
#   'num_option': 4,
#   'qid': 'Interaction_T1_277',
#   'a0': 'The door.',
#   'a1': 'The box.',
#   'a2': 'The bag.',
#   'a3': 'The window.',
#   'answer': 1,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 24.9,
#   'end': 31.1},
#  {'video': '2P7A9',
#   'num_option': 4,
#   'qid': 'Interaction_T1_278',
#   'a0': 'The dish.',
#   'a1': 'The laptop.',
#   'a2': 'The pillow.',
#   'a3': 'The broom.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 18.8,
#   'end': 24.0},
#  {'video': '2P7A9',
#   'num_option': 4,
#   'qid': 'Interaction_T1_279',
#   'a0': 'The sandwich.',
#   'a1': 'The picture.',
#   'a2': 'The dish.',
#   'a3': 'The phone/camera.',
#   'answer': 1,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 26.5,
#   'end': 35.8},
#  {'video': '2P7A9',
#   'num_option': 4,
#   'qid': 'Interaction_T1_280',
#   'a0': 'The sofa/couch.',
#   'a1': 'The table.',
#   'a2': 'The floor.',
#   'a3': 'The bed.',
#   'answer': 1,
#   'question': 'Which object was sat at by the person?',
#   'q_events': ['sat'],
#   'start': 28.3,
#   'end': 37.0},
#  {'video': '2P7A9',
#   'num_option': 4,
#   'qid': 'Interaction_T1_281',
#   'a0': 'The broom.',
#   'a1': 'The clothes.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The table.',
#   'answer': 3,
#   'question': 'Which object was tidied up by the person?',
#   'q_events': ['tidied up by the person'],
#   'start': 28.9,
#   'end': 37.0},
#  {'video': '2P7A9',
#   'num_option': 4,
#   'qid': 'Interaction_T1_282',
#   'a0': 'The dish.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The picture.',
#   'a3': 'The book.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 22.0,
#   'end': 26.7},
#  {'video': '3VT73',
#   'num_option': 4,
#   'qid': 'Interaction_T1_283',
#   'a0': 'The door.',
#   'a1': 'The book.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The box.',
#   'answer': 1,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 7.7,
#   'end': 12.4},
#  {'video': '3VT73',
#   'num_option': 4,
#   'qid': 'Interaction_T1_284',
#   'a0': 'The clothes.',
#   'a1': 'The food.',
#   'a2': 'The blanket.',
#   'a3': 'The book.',
#   'answer': 3,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 8.4,
#   'end': 13.1},
#  {'video': '3VT73',
#   'num_option': 4,
#   'qid': 'Interaction_T1_285',
#   'a0': 'The broom.',
#   'a1': 'The phone/camera.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The food.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 10.4,
#   'end': 15.9},
#  {'video': 'AOK1L',
#   'num_option': 4,
#   'qid': 'Interaction_T1_292',
#   'a0': 'The broom.',
#   'a1': 'The towel.',
#   'a2': 'The clothes.',
#   'a3': 'The table.',
#   'answer': 3,
#   'question': 'Which object was tidied up by the person?',
#   'q_events': ['tidied up by the person'],
#   'start': 32.1,
#   'end': 36.0},
#  {'video': 'JTXAM',
#   'num_option': 4,
#   'qid': 'Interaction_T1_296',
#   'a0': 'The door.',
#   'a1': 'The refrigerator.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The book.',
#   'answer': 3,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 13.8,
#   'end': 19.1},
#  {'video': 'H608V',
#   'num_option': 4,
#   'qid': 'Interaction_T1_300',
#   'a0': 'The sandwich.',
#   'a1': 'The bed.',
#   'a2': 'The door.',
#   'a3': 'The medicine.',
#   'answer': 0,
#   'question': 'Which object was eaten by the person?',
#   'q_events': ['eaten by the person'],
#   'start': 0.9,
#   'end': 7.9},
#  {'video': 'H608V',
#   'num_option': 4,
#   'qid': 'Interaction_T1_301',
#   'a0': 'The clothes.',
#   'a1': 'The book.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The food.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 10.1,
#   'end': 15.4},
#  {'video': 'H608V',
#   'num_option': 4,
#   'qid': 'Interaction_T1_302',
#   'a0': 'The shoe.',
#   'a1': 'The blanket.',
#   'a2': 'The sandwich.',
#   'a3': 'The pillow.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 3.1,
#   'end': 8.4},
#  {'video': 'CIUVA',
#   'num_option': 4,
#   'qid': 'Interaction_T1_303',
#   'a0': 'The box.',
#   'a1': 'The phone/camera.',
#   'a2': 'The towel.',
#   'a3': 'The clothes.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 25.6,
#   'end': 32.6},
#  {'video': 'CIUVA',
#   'num_option': 4,
#   'qid': 'Interaction_T1_304',
#   'a0': 'The towel.',
#   'a1': 'The blanket.',
#   'a2': 'The pillow.',
#   'a3': 'The bag.',
#   'answer': 0,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 33.2,
#   'end': 38.8},
#  {'video': 'CIUVA',
#   'num_option': 4,
#   'qid': 'Interaction_T1_305',
#   'a0': 'The shoe.',
#   'a1': 'The book.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The bag.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 6.4,
#   'end': 12.0},
#  {'video': 'CIUVA',
#   'num_option': 4,
#   'qid': 'Interaction_T1_306',
#   'a0': 'The window.',
#   'a1': 'The closet/cabinet.',
#   'a2': 'The laptop.',
#   'a3': 'The refrigerator.',
#   'answer': 3,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 46.5,
#   'end': 55.0},
#  {'video': 'S7OTQ',
#   'num_option': 4,
#   'qid': 'Interaction_T1_311',
#   'a0': 'The bag.',
#   'a1': 'The door.',
#   'a2': 'The window.',
#   'a3': 'The book.',
#   'answer': 3,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 1.2,
#   'end': 7.2},
#  {'video': 'S7OTQ',
#   'num_option': 4,
#   'qid': 'Interaction_T1_314',
#   'a0': 'The sandwich.',
#   'a1': 'The food.',
#   'a2': 'The shoe.',
#   'a3': 'The book.',
#   'answer': 3,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 0.0,
#   'end': 7.9},
#  {'video': 'FRGXE',
#   'num_option': 4,
#   'qid': 'Interaction_T1_322',
#   'a0': 'The laptop.',
#   'a1': 'The door.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The box.',
#   'answer': 3,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 19.6,
#   'end': 23.0},
#  {'video': 'FRGXE',
#   'num_option': 4,
#   'qid': 'Interaction_T1_323',
#   'a0': 'The broom.',
#   'a1': 'The blanket.',
#   'a2': 'The towel.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 10.8,
#   'end': 15.6},
#  {'video': 'GFPDD',
#   'num_option': 4,
#   'qid': 'Interaction_T1_325',
#   'a0': 'The food.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The shoe.',
#   'a3': 'The picture.',
#   'answer': 0,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 7.3,
#   'end': 13.0},
#  {'video': 'GFPDD',
#   'num_option': 4,
#   'qid': 'Interaction_T1_326',
#   'a0': 'The dish.',
#   'a1': 'The clothes.',
#   'a2': 'The food.',
#   'a3': 'The laptop.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 20.9,
#   'end': 29.0},
#  {'video': 'YE47Y',
#   'num_option': 4,
#   'qid': 'Interaction_T1_330',
#   'a0': 'The clothes.',
#   'a1': 'The food.',
#   'a2': 'The phone/camera.',
#   'a3': 'The sandwich.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 5.6,
#   'end': 11.2},
#  {'video': 'YE47Y',
#   'num_option': 4,
#   'qid': 'Interaction_T1_331',
#   'a0': 'The cup/glass/bottle.',
#   'a1': 'The blanket.',
#   'a2': 'The food.',
#   'a3': 'The phone/camera.',
#   'answer': 3,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 3.8,
#   'end': 8.3},
#  {'video': 'YE47Y',
#   'num_option': 4,
#   'qid': 'Interaction_T1_332',
#   'a0': 'The cup/glass/bottle.',
#   'a1': 'The phone/camera.',
#   'a2': 'The pillow.',
#   'a3': 'The book.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 7.7,
#   'end': 12.3},
#  {'video': '13XM4',
#   'num_option': 4,
#   'qid': 'Interaction_T1_333',
#   'a0': 'The phone/camera.',
#   'a1': 'The box.',
#   'a2': 'The shoe.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 3,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 9.3,
#   'end': 13.6},
#  {'video': '2B8ML',
#   'num_option': 4,
#   'qid': 'Interaction_T1_334',
#   'a0': 'The shoe.',
#   'a1': 'The picture.',
#   'a2': 'The sandwich.',
#   'a3': 'The phone/camera.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 9.1,
#   'end': 14.9},
#  {'video': '2B8ML',
#   'num_option': 4,
#   'qid': 'Interaction_T1_335',
#   'a0': 'The laptop.',
#   'a1': 'The door.',
#   'a2': 'The box.',
#   'a3': 'The book.',
#   'answer': 2,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 4.8,
#   'end': 9.6},
#  {'video': 'LE7PM',
#   'num_option': 4,
#   'qid': 'Interaction_T1_340',
#   'a0': 'The pillow.',
#   'a1': 'The bag.',
#   'a2': 'The shoe.',
#   'a3': 'The food.',
#   'answer': 3,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 0.0,
#   'end': 4.1},
#  {'video': 'LE7PM',
#   'num_option': 4,
#   'qid': 'Interaction_T1_341',
#   'a0': 'The food.',
#   'a1': 'The clothes.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The paper/notebook.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 0.0,
#   'end': 4.4},
#  {'video': 'JKGTN',
#   'num_option': 4,
#   'qid': 'Interaction_T1_343',
#   'a0': 'The clothes.',
#   'a1': 'The pillow.',
#   'a2': 'The phone/camera.',
#   'a3': 'The sandwich.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 0.0,
#   'end': 3.8},
#  {'video': 'JKGTN',
#   'num_option': 4,
#   'qid': 'Interaction_T1_344',
#   'a0': 'The bag.',
#   'a1': 'The dish.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The pillow.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
# ...
#  {'video': '4KYZH',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1807',
#   'a0': 'The clothes.',
#   'a1': 'The food.',
#   'a2': 'The picture.',
#   'a3': 'The dish.',
#   'answer': 1,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 7.7,
#   'end': 13.2},
#  {'video': 'K6KNC',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1813',
#   'a0': 'The floor.',
#   'a1': 'The bed.',
#   'a2': 'The table.',
#   'a3': 'The sofa/couch.',
#   'answer': 0,
#   'question': 'Which object was sat on by the person?',
#   'q_events': ['sat'],
#   'start': 0.0,
#   'end': 7.0},
#  {'video': 'K6KNC',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1814',
#   'a0': 'The book.',
#   'a1': 'The sofa/couch.',
#   'a2': 'The floor.',
#   'a3': 'The bed.',
#   'answer': 2,
#   'question': 'Which object was lied on by the person?',
#   'q_events': ['lied'],
#   'start': 0.0,
#   'end': 7.0},
#  {'video': '5UNMN',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1819',
#   'a0': 'The floor.',
#   'a1': 'The sofa/couch.',
#   'a2': 'The bed.',
#   'a3': 'The table.',
#   'answer': 3,
#   'question': 'Which object was sat at by the person?',
#   'q_events': ['sat'],
#   'start': 8.9,
#   'end': 15.0},
#  {'video': 'OE2OX',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1820',
#   'a0': 'The door.',
#   'a1': 'The box.',
#   'a2': 'The bag.',
#   'a3': 'The closet/cabinet.',
#   'answer': 3,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 2.2,
#   'end': 8.5},
#  {'video': 'OE2OX',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1821',
#   'a0': 'The food.',
#   'a1': 'The sandwich.',
#   'a2': 'The blanket.',
#   'a3': 'The towel.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 4.7,
#   'end': 13.0},
#  {'video': 'OE2OX',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1822',
#   'a0': 'The food.',
#   'a1': 'The bag.',
#   'a2': 'The clothes.',
#   'a3': 'The broom.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 2.2,
#   'end': 9.9},
#  {'video': 'OE2OX',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1823',
#   'a0': 'The door.',
#   'a1': 'The book.',
#   'a2': 'The window.',
#   'a3': 'The closet/cabinet.',
#   'answer': 3,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 11.9,
#   'end': 18.0},
#  {'video': '9AC1T',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1827',
#   'a0': 'The sofa/couch.',
#   'a1': 'The floor.',
#   'a2': 'The bed.',
#   'a3': 'The table.',
#   'answer': 3,
#   'question': 'Which object was sat at by the person?',
#   'q_events': ['sat'],
#   'start': 3.1,
#   'end': 12.2},
#  {'video': 'XRG9K',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1830',
#   'a0': 'The shoe.',
#   'a1': 'The book.',
#   'a2': 'The food.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 10.2,
#   'end': 16.0},
#  {'video': 'BJ7YW',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1831',
#   'a0': 'The dish.',
#   'a1': 'The towel.',
#   'a2': 'The shoe.',
#   'a3': 'The picture.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 0.0,
#   'end': 6.5},
#  {'video': 'BJ7YW',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1832',
#   'a0': 'The phone/camera.',
#   'a1': 'The bag.',
#   'a2': 'The clothes.',
#   'a3': 'The shoe.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 0.0,
#   'end': 8.8},
#  {'video': '2KMGY',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1835',
#   'a0': 'The door.',
#   'a1': 'The box.',
#   'a2': 'The book.',
#   'a3': 'The bag.',
#   'answer': 3,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 3.7,
#   'end': 9.2},
#  {'video': '2KMGY',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1836',
#   'a0': 'The sofa/couch.',
#   'a1': 'The floor.',
#   'a2': 'The bed.',
#   'a3': 'The table.',
#   'answer': 1,
#   'question': 'Which object was sat on by the person?',
#   'q_events': ['sat'],
#   'start': 0.0,
#   'end': 3.4},
#  {'video': 'U7O1U',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1837',
#   'a0': 'The cup/glass/bottle.',
#   'a1': 'The clothes.',
#   'a2': 'The sandwich.',
#   'a3': 'The pillow.',
#   'answer': 1,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 10.8,
#   'end': 15.9},
#  {'video': 'U7O1U',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1838',
#   'a0': 'The blanket.',
#   'a1': 'The bag.',
#   'a2': 'The clothes.',
#   'a3': 'The pillow.',
#   'answer': 2,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 10.8,
#   'end': 16.1},
#  {'video': 'IFRT0',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1839',
#   'a0': 'The broom.',
#   'a1': 'The dish.',
#   'a2': 'The food.',
#   'a3': 'The blanket.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 13.9,
#   'end': 21.1},
#  {'video': '4UXE3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1840',
#   'a0': 'The cup/glass/bottle.',
#   'a1': 'The window.',
#   'a2': 'The dish.',
#   'a3': 'The clothes.',
#   'answer': 0,
#   'question': 'Which object was washed by the person?',
#   'q_events': ['washed by the person'],
#   'start': 24.7,
#   'end': 31.4},
#  {'video': '4UXE3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1841',
#   'a0': 'The closet/cabinet.',
#   'a1': 'The box.',
#   'a2': 'The refrigerator.',
#   'a3': 'The bag.',
#   'answer': 0,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 0.0,
#   'end': 5.5},
#  {'video': '4UXE3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1842',
#   'a0': 'The dish.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The picture.',
#   'a3': 'The paper/notebook.',
#   'answer': 0,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 4.6,
#   'end': 9.4},
#  {'video': '4UXE3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1843',
#   'a0': 'The towel.',
#   'a1': 'The picture.',
#   'a2': 'The food.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 3,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 24.5,
#   'end': 29.1},
#  {'video': 'VXJS4',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1845',
#   'a0': 'The bag.',
#   'a1': 'The door.',
#   'a2': 'The window.',
#   'a3': 'The refrigerator.',
#   'answer': 1,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 0.0,
#   'end': 4.0},
#  {'video': '1GII3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1849',
#   'a0': 'The towel.',
#   'a1': 'The blanket.',
#   'a2': 'The broom.',
#   'a3': 'The table.',
#   'answer': 0,
#   'question': 'Which object was tidied up by the person?',
#   'q_events': ['tidied up by the person'],
#   'start': 2.3,
#   'end': 7.2},
#  {'video': '1GII3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1850',
#   'a0': 'The blanket.',
#   'a1': 'The food.',
#   'a2': 'The shoe.',
#   'a3': 'The cup/glass/bottle.',
#   'answer': 1,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 8.6,
#   'end': 14.6},
#  {'video': '1GII3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1852',
#   'a0': 'The blanket.',
#   'a1': 'The clothes.',
#   'a2': 'The pillow.',
#   'a3': 'The towel.',
#   'answer': 3,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 1.6,
#   'end': 6.6},
#  {'video': '1GII3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1853',
#   'a0': 'The book.',
#   'a1': 'The paper/notebook.',
#   'a2': 'The towel.',
#   'a3': 'The box.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 1.9,
#   'end': 7.5},
#  {'video': '1GII3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1854',
#   'a0': 'The clothes.',
#   'a1': 'The towel.',
#   'a2': 'The picture.',
#   'a3': 'The sandwich.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 1.4,
#   'end': 6.0},
#  {'video': '1GII3',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1855',
#   'a0': 'The table.',
#   'a1': 'The window.',
#   'a2': 'The clothes.',
#   'a3': 'The dish.',
#   'answer': 2,
#   'question': 'Which object was washed by the person?',
#   'q_events': ['washed by the person'],
#   'start': 0.0,
#   'end': 3.9},
#  {'video': '86E2E',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1856',
#   'a0': 'The sofa/couch.',
#   'a1': 'The floor.',
#   'a2': 'The bed.',
#   'a3': 'The table.',
#   'answer': 1,
#   'question': 'Which object was sat on by the person?',
#   'q_events': ['sat'],
#   'start': 0.0,
#   'end': 8.8},
#  {'video': '86E2E',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1857',
#   'a0': 'The dish.',
#   'a1': 'The box.',
#   'a2': 'The food.',
#   'a3': 'The broom.',
#   'answer': 0,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 7.8,
#   'end': 13.0},
#  {'video': '86E2E',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1858',
#   'a0': 'The book.',
#   'a1': 'The blanket.',
#   'a2': 'The clothes.',
#   'a3': 'The pillow.',
#   'answer': 3,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 3.6,
#   'end': 8.5},
#  {'video': '86E2E',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1859',
#   'a0': 'The broom.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The pillow.',
#   'a3': 'The dish.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 1.4,
#   'end': 6.2},
#  {'video': '5NV2Z',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1860',
#   'a0': 'The laptop.',
#   'a1': 'The bag.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The phone/camera.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 5.1,
#   'end': 10.2},
#  {'video': 'MKMFK',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1861',
#   'a0': 'The laptop.',
#   'a1': 'The box.',
#   'a2': 'The shoe.',
#   'a3': 'The broom.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 4.7,
#   'end': 11.0},
#  {'video': 'NX8X9',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1863',
#   'a0': 'The book.',
#   'a1': 'The window.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The refrigerator.',
#   'answer': 0,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 13.8,
#   'end': 18.2},
#  {'video': 'BM3UJ',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1864',
#   'a0': 'The window.',
#   'a1': 'The laptop.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The door.',
#   'answer': 3,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 3.4,
#   'end': 9.8},
#  {'video': 'BM3UJ',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1865',
#   'a0': 'The laptop.',
#   'a1': 'The clothes.',
#   'a2': 'The phone/camera.',
#   'a3': 'The dish.',
#   'answer': 3,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 4.9,
#   'end': 10.4},
#  {'video': 'BM3UJ',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1866',
#   'a0': 'The book.',
#   'a1': 'The door.',
#   'a2': 'The closet/cabinet.',
#   'a3': 'The laptop.',
#   'answer': 1,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 5.9,
#   'end': 12.9},
#  {'video': 'HJ4B1',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1867',
#   'a0': 'The sandwich.',
#   'a1': 'The blanket.',
#   'a2': 'The paper/notebook.',
#   'a3': 'The laptop.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 7.6,
#   'end': 13.3},
#  {'video': 'HJ4B1',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1868',
#   'a0': 'The cup/glass/bottle.',
#   'a1': 'The shoe.',
#   'a2': 'The phone/camera.',
#   'a3': 'The picture.',
#   'answer': 3,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 13.1,
#   'end': 19.9},
#  {'video': 'HJ4B1',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1869',
#   'a0': 'The cup/glass/bottle.',
#   'a1': 'The laptop.',
#   'a2': 'The book.',
#   'a3': 'The box.',
#   'answer': 1,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 7.3,
#   'end': 12.4},
#  {'video': 'BDY1V',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1874',
#   'a0': 'The towel.',
#   'a1': 'The pillow.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The clothes.',
#   'answer': 1,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 0.0,
#   'end': 5.7},
#  {'video': 'BDY1V',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1875',
#   'a0': 'The blanket.',
#   'a1': 'The clothes.',
#   'a2': 'The shoe.',
#   'a3': 'The pillow.',
#   'answer': 1,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 18.0,
#   'end': 23.8},
#  {'video': 'BDY1V',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1876',
#   'a0': 'The pillow.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The broom.',
#   'a3': 'The clothes.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 18.0,
#   'end': 23.8},
#  {'video': '2AG8W',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1877',
#   'a0': 'The book.',
#   'a1': 'The pillow.',
#   'a2': 'The towel.',
#   'a3': 'The clothes.',
#   'answer': 3,
#   'question': 'Which object was thrown by the person?',
#   'q_events': ['thrown by the person'],
#   'start': 4.0,
#   'end': 8.7},
#  {'video': '2AG8W',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1878',
#   'a0': 'The cup/glass/bottle.',
#   'a1': 'The food.',
#   'a2': 'The clothes.',
#   'a3': 'The picture.',
#   'answer': 2,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 4.3,
#   'end': 9.7},
#  {'video': 'KERO6',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1879',
#   'a0': 'The food.',
#   'a1': 'The broom.',
#   'a2': 'The cup/glass/bottle.',
#   'a3': 'The phone/camera.',
#   'answer': 0,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 11.4,
#   'end': 16.9},
#  {'video': 'KERO6',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1880',
#   'a0': 'The pillow.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The food.',
#   'a3': 'The dish.',
#   'answer': 2,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 9.6,
#   'end': 17.1},
#  {'video': '0LHWF',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1881',
#   'a0': 'The door.',
#   'a1': 'The closet/cabinet.',
#   'a2': 'The window.',
#   'a3': 'The book.',
#   'answer': 3,
#   'question': 'Which object was opened by the person?',
#   'q_events': ['opened by the person'],
#   'start': 0.0,
#   'end': 6.7},
#  {'video': '0LHWF',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1882',
#   'a0': 'The food.',
#   'a1': 'The cup/glass/bottle.',
#   'a2': 'The box.',
#   'a3': 'The book.',
#   'answer': 3,
#   'question': 'Which object was taken by the person?',
#   'q_events': ['taken by the person'],
#   'start': 0.0,
#   'end': 4.7},
#  {'video': '0LHWF',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1883',
#   'a0': 'The window.',
#   'a1': 'The door.',
#   'a2': 'The laptop.',
#   'a3': 'The book.',
#   'answer': 3,
#   'question': 'Which object was closed by the person?',
#   'q_events': ['closed by the person'],
#   'start': 14.6,
#   'end': 19.4},
#  {'video': '0LHWF',
#   'num_option': 4,
#   'qid': 'Interaction_T1_1884',
#   'a0': 'The cup/glass/bottle.',
#   'a1': 'The clothes.',
#   'a2': 'The bag.',
#   'a3': 'The book.',
#   'answer': 3,
#   'question': 'Which object was put down by the person?',
#   'q_events': ['put down by the person'],
#   'start': 0.0,
#   'end': 4.0},
#  ...]
